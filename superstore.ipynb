# %% [markdown]
# ## **SUPERSTORE ANALYSIS**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import plotly.express as px

# %% [markdown]
# ## **Import raw data**

# %%
file_path = r"C:\Program Files (x86)\Microsoft Office\Office12\Library\Analysis\Sample - Superstore.csv"
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %% [markdown]
# ## **Meta data of row data**

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
df.tail(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9985    9986  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %%
print("The Metadata of the dataset:", df.shape)
# Out:
# The Metadata of the dataset: (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
print("--- Basic Statistics ---")
stats = df[['Sales', 'Quantity', 'Discount', 'Profit']].describe()
print(stats)
# Out:
# --- Basic Statistics ---
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    x='Category', 
    y='Sales', 
    data=df, 
    estimator=sum, 
    errorbar=None, 
    hue='Category', 
    legend=False, 
    palette='viridis'
)

plt.title('Total Sales by Category')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Sales', y='Profit', hue='Segment', data=df)
plt.title('Sales vs Profit by Segment')
plt.show()

# %%
plt.figure(figsize=(10,6))
top_cities = df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(10)
top_cities.plot(kind='bar' , color='salmon')
plt.title('Top 10 Most profitabel Cities')
plt.ylabel('Total Profit')
plt.xticks(rotation=45)
plt.show()

# %%
df['Profit_Margin'] = (df['Profit'] / df['Sales']) * 100

# %%
margin_analysis = df.groupby('Region')['Profit_Margin'].mean()
print("\n--- Average Profit Margin by Region ---")
print(margin_analysis)
# Out:
# --- Average Profit Margin by Region ---
# Region
# Central   -10.407294
# East       16.722696
# South      16.351903
# West       21.948662
# Name: Profit_Margin, dtype: float64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Month_Year'] = df['Order Date'].dt.to_period('M')
monthly_sales = df.groupby('Month_Year')['Sales'].sum()

# %%
plt.figure(figsize=(12, 5))
monthly_sales.plot(kind='line', marker='o', color='green')
plt.title('Monthly Sales Trend')
plt.grid(True)
plt.show()

# %%
sns.boxplot(x=df['Profit'])
plt.title('Profit Distribution & Outliers')
plt.show()

# %%
corr_matrix = df[['Sales', 'Quantity', 'Discount', 'Profit']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='RdYlGn', center=0)
plt.title('Correlation Matrix (Impact of Discount on Profit)')
plt.show()

# %%
plt.figure(figsize=(12, 6))
# Comparing Profit density across different Regions
sns.violinplot(x='Region', y='Profit', data=df[df['Profit'].between(-500, 500)], inner="quart")
plt.title('Profit Density Distribution by Region')
plt.show()

# %%
plt.figure(figsize=(10, 6))
# Using regplot to see the trend line
sns.regplot(x='Sales', y='Profit', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
plt.title('Regression Analysis: Sales vs Profit Trend')
plt.show()
